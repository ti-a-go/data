# %%
import wikipedia

# %%
wikipedia.set_lang("pt")

# %%
page = wikipedia.page("brasil")
page.summary
# Out:
# "Brasil (localmente [bɾaˈziw]), oficialmente República Federativa do Brasil (? escutar), é o maior país da América do Sul e da região da América Latina, sendo o quinto maior do mundo em área territorial (equivalente a 47,3% do território sul-americano), com 8 510 417,771 km², e o sétimo em população (com 203 milhões de habitantes, em agosto de 2022). É o único país na América onde se fala majoritariamente a língua portuguesa e o maior país lusófono do planeta, além de ser uma das nações mais multiculturais e etnicamente diversas, em decorrência da forte imigração oriunda de variados locais do mundo. Sua atual Constituição, promulgada em 1988, concebe o Brasil como uma república federativa presidencialista, formada pela união dos 26 estados, do Distrito Federal e dos 5 571 municípios.Banhado pelo Oceano Atlântico, o Brasil tem um litoral de 7 491 km e faz fronteira com todos os outros países sul-americanos, exceto Chile e Equador, sendo limitado a norte pela Venezuela, Guiana, Surinam
# ...

# %% [markdown]
# # WikipediaPage Properties

# %% [markdown]
# ## Categories

# %%
page.categories
# Out:
# ['Categoria:!Artigos bons na Wikipédia em alemão',
#  'Categoria:!Artigos bons na Wikipédia em ucraniano',
#  'Categoria:!Artigos com ligações inativas',
#  'Categoria:!Artigos com áudio',
#  'Categoria:!Artigos destacados',
#  'Categoria:!Artigos destacados na Wikipédia em africâner',
#  'Categoria:!Artigos destacados na Wikipédia em búlgaro',
#  'Categoria:!Artigos destacados na Wikipédia em canarês',
#  'Categoria:!Artigos destacados na Wikipédia em croata',
#  'Categoria:!Artigos destacados na Wikipédia em espanhol',
#  'Categoria:!Artigos destacados na Wikipédia em romeno',
#  'Categoria:!Artigos destacados na Wikipédia em siciliano',
#  'Categoria:!CS1 espanhol-fontes em língua (es)',
#  'Categoria:!CS1 inglês-fontes em língua (en)',
#  'Categoria:!CS1 manut: Nomes múltiplos: lista de autores',
#  'Categoria:!Predefinição Artigo principal com parâmetro prefixo',
#  'Categoria:!Páginas com argumentos formatnum não numéricos',
# ...

# %% [markdown]
# ## Content

# %%
page.content
# Out:
# 'Brasil (localmente [bɾaˈziw]), oficialmente República Federativa do Brasil (? escutar), é o maior país da América do Sul e da região da América Latina, sendo o quinto maior do mundo em área territorial (equivalente a 47,3% do território sul-americano), com 8 510 417,771 km², e o sétimo em população (com 203 milhões de habitantes, em agosto de 2022). É o único país na América onde se fala majoritariamente a língua portuguesa e o maior país lusófono do planeta, além de ser uma das nações mais multiculturais e etnicamente diversas, em decorrência da forte imigração oriunda de variados locais do mundo. Sua atual Constituição, promulgada em 1988, concebe o Brasil como uma república federativa presidencialista, formada pela união dos 26 estados, do Distrito Federal e dos 5 571 municípios.Banhado pelo Oceano Atlântico, o Brasil tem um litoral de 7 491 km e faz fronteira com todos os outros países sul-americanos, exceto Chile e Equador, sendo limitado a norte pela Venezuela, Guiana, Surinam
# ...

# %% [markdown]
# ## Coordinates

# %%
page.coordinates
# Out:
# (Decimal('-10'), Decimal('-55'))

# %% [markdown]
# ## HTML

# %%
# page.html()

# %% [markdown]
# ## Images

# %%
page.images
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/a/a5/1-real-2019-25-anos.png',
#  'https://upload.wikimedia.org/wikipedia/commons/5/56/10_03_2022_Opera%C3%A7%C3%A3o_Repatria%C3%A7%C3%A3o_-_Chegada_dos_Brasileiros_e_Estrangeiros_provenientes_da_Ucr%C3%A2nia_%2851931465965%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/71/200923ASO_Anderson_Soares_50.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4b/Aclama%C3%A7%C3%A3o_do_rei_Dom_Jo%C3%A3o_VI_no_Rio_de_Janeiro.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/87/Amanhecer_no_Hercules_--.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/18/Amazon_CIAT_%285%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/ca/Americas_%28orthographic_projection%29.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/65/Ant%C3%B4nio_Parreiras_-_Pris%C3%A3o_de_Tiradentes%2C_1914.jpg',
# ...

# %% [markdown]
# ## Links

# %%
page.links
# Out:
# ['.br',
#  '1.ª Cúpula Sul-Americana',
#  '1.ª Cúpula da Unasul',
#  '12 de outubro',
#  '15 de novembro',
#  '1 de dezembro',
#  '1 de janeiro',
#  '1 de maio',
#  '2.ª Cúpula Sul-Americana',
#  '2.ª Cúpula da Unasul',
#  '21 de abril',
#  '25 de dezembro',
#  '2 de novembro',
#  '3.ª Cúpula da Unasul',
#  '4.ª Cúpula Sul-Americana',
#  '4.ª Cúpula da Unasul',
#  '5.ª Cúpula Sul-Americana',
#  '5.ª Cúpula da Unasul',
#  '6.ª Cúpula Sul-Americana',
#  '6.ª Cúpula da Unasul',
#  '7.ª Cúpula da Unasul',
#  '7 de setembro',
#  '8.ª Cúpula da Unasul',
#  '9.ª Cúpula da Unasul',
#  'A Justiça (escultura)',
#  'Abdicação de Pedro I do Brasil',
#  'Abertura política',
#  'Abstracionismo',
#  'Academia Brasileira de Letras',
#  'Academia Imperial de Belas Artes',
#  'Academismo no Brasil',
#  'Académie des Beaux-Arts',
#  'Acarajé',
#  'Acelerador de partículas',
#  'Acordo Ortográfico de 1990',
#  'Acordo de Cartagena',
# ...

# %% [markdown]
# ## Parent ID

# %%
page.parent_id
# Out:
# 66823299

# %% [markdown]
# ## References

# %%
page.references
# Out:
# ['https://www.cia.gov/library/publications/the-world-factbook/geos/br.html',
#  'http://bibliotecadigital.fgv.br/dspace/bitstream/handle/10438/9937/vozes.pdf?sequence=1',
#  'http://www.usp.br/jorusp/arquivo/2003/jusp667/pag0304.htm',
#  'http://www.bgfconsultoria.com.br/pag/documents/Rio_Oil_Gas.htm',
#  'http:ftp://ftp.ibge.gov.br/Censos/Censo_Demografico_2010/Caracteristicas_Gerais_Religiao_Deficiencia/tab1_4.pdf%7CResultados',
#  'http://press.princeton.edu/chapters/s8857.html',
#  'http://www2.docentes.uneb.br/lucianolima/artigos/KEW_GARDEN2.doc',
#  'http://books.google.com/books?id=nR40G_3UyV8C&pg=PT260',
#  'http://books.google.co.uk/books?id=wokuHhx1AOUC&pg=PA1834#v=onepage&q&f=false',
#  'http://www.ufjf.br/ladem/files/2009/08/cresc-pop-e-estrutura-demografica-no-br.pdf',
#  'http://web.archive.org/web/20120118154154/http://www2.docentes.uneb.br/lucianolima/artigos/KEW_GARDEN2.doc',
# ...

# %% [markdown]
# ## Sections

# %%
page.sections
# Out:
# []

# %%
if page.sections:
    page.section[page.sections[0]]

# %% [markdown]
# ## Summary

# %%
page.summary
# Out:
# "Brasil (localmente [bɾaˈziw]), oficialmente República Federativa do Brasil (? escutar), é o maior país da América do Sul e da região da América Latina, sendo o quinto maior do mundo em área territorial (equivalente a 47,3% do território sul-americano), com 8 510 417,771 km², e o sétimo em população (com 203 milhões de habitantes, em agosto de 2022). É o único país na América onde se fala majoritariamente a língua portuguesa e o maior país lusófono do planeta, além de ser uma das nações mais multiculturais e etnicamente diversas, em decorrência da forte imigração oriunda de variados locais do mundo. Sua atual Constituição, promulgada em 1988, concebe o Brasil como uma república federativa presidencialista, formada pela união dos 26 estados, do Distrito Federal e dos 5 571 municípios.Banhado pelo Oceano Atlântico, o Brasil tem um litoral de 7 491 km e faz fronteira com todos os outros países sul-americanos, exceto Chile e Equador, sendo limitado a norte pela Venezuela, Guiana, Surinam
# ...

# %% [markdown]
# # Sandbox

# %%
page.title
# Out:
# 'Brasil'
